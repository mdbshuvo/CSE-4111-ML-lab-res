# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
x1 = np.random.normal(loc=11, scale=2.0, size=100)
y1 = np.random.normal(loc=5, scale=3.0, size=100)

x2 = np.random.normal(loc=3, scale=1.5, size=75)
y2 = np.random.normal(loc=15, scale=2.0, size=75)

x3 = np.random.normal(loc=16, scale=1, size=50)
y3 = np.random.normal(loc=20.5, scale=1.5, size=50)

# %%
plt.scatter(x1, y1, label="cluster1")
plt.scatter(x2, y2, label="cluster2")
plt.scatter(x3, y3, label="cluster2")

plt.legend()
plt.show()

# %%
X = np.expand_dims(np.append(np.append(x1, x2), x3), axis=1)
Y = np.expand_dims(np.append(np.append(y1, y2), y3), axis=1)

data = np.concatenate((X,Y), axis=1)

# %%
X.shape
# Out:
# (225, 1)

# %%
data.shape
# Out:
# (225, 2)

# %%
data[:5]
# Out:
# array([[ 9.07100937,  5.54374923],
#        [12.23238949,  8.38091171],
#        [10.41616133,  0.55033443],
#        [13.18546628,  3.5607303 ],
#        [11.3302722 ,  8.60979806]])

# %%
plt.scatter(data[:, 0], data[:, 1])

# %% [markdown]
# ## Model

# %%
def eucl_dist(p1, p2):
    ### dist = Implement this 
    ##### your code #####
    
    return dist

# %%
def KMeans(dataPoints, k):
    # takes data points returns k points as cluster centroid
    # Select random k points
    ### cen = ? 
    ##### your code #####
    
    # Converting "cen" to a numpy array
    cen = np.array(cen)
    
    # Loop
    epoch = 10
    for e in range(epoch):
        # Labeling
        label = []
        for d in dataPoints:
            # calculate label for each data point 
            ##### your code #####
        
        label = np.array(label)
        
        # for visuals
        for c in range(k):
            kth_data = dataPoints[label==c]
            plt.scatter(kth_data[:, 0], kth_data[:, 1], label="cluster "+str(c+1))
            plt.scatter(cen[c][0], cen[c][1], label="centroid "+str(c+1), marker="*")
        plt.legend()
        plt.show()
        
        # New centroid calculation
        for c in range(k):
            # Mean of the clustered points
            ##### your code #####
    
    return cen

# %%
KMeans(data, 2) ### Call this function
